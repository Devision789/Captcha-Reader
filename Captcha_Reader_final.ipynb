# %% [markdown]
# <a href="https://colab.research.google.com/github/Devision789/Captcha-Reader/blob/main/Captcha_Reader_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Devision789***
#
# **https://github.com/Devision789**
#
# ***ĐỌC MÃ CAPTCHA ***
#
# lưu ý nếu các bạn chạy local thì xem xét trang github inference
# yêu cầu bản python và cài đúng nếu bản python không phù hợp thì hệ thống sẽ báo lỗi no module name distubils ( có thể package khác mình quên tên nó rồi )
# Mọi người cần hỗ trợ về vấn đề gì có thể liên hệ mình.

# %%
# !pip install inference
# Out:
# Requirement already satisfied: inference in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: APScheduler<=3.10.1 in /usr/local/lib/python3.10/dist-packages (from inference) (3.10.1)
# Requirement already satisfied: cython<=3.0.0 in /usr/local/lib/python3.10/dist-packages (from inference) (3.0.0)
# Requirement already satisfied: python-dotenv<=2.0.0 in /usr/local/lib/python3.10/dist-packages (from inference) (1.0.1)
# Requirement already satisfied: fastapi<0.111,>=0.100 in /usr/local/lib/python3.10/dist-packages (from inference) (0.110.3)
# Requirement already satisfied: numpy<=1.26.4 in /usr/local/lib/python3.10/dist-packages (from inference) (1.25.2)
# Requirement already satisfied: opencv-python<=4.8.0.76 in /usr/local/lib/python3.10/dist-packages (from inference) (4.8.0.76)
# Requirement already satisfied: piexif<=1.1.3 in /usr/local/lib/python3.10/dist-packages (from inference) (1.1.3)
# Requirement already satisfied: pillow<11.0 in /usr/local/lib/python3.10/dist-packages (from inference) (9.4.0)
# Requirement already satisfied: prometheus-fastapi-instrumentator<=6.0.0 in /usr/local/lib/python3.10/dist-packages (from inference) (6.0.0)
# Requirement already satisfied: redis<6.0.0 in /usr/local/lib/python3.10/dist-packages (from inference) (5.0.7)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from inference) (2.31.0)
# Requirement already satisfied: rich<=13.5.2 in /usr/local/lib/python3.10/dist-packages (from inference) (13.5.2)
# Requirement already satisfied: supervision<1.0.0,>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from inference) (0.22.0)
# Requirement already satisfied: pybase64<2.0.0 in /usr/local/lib/python3.10/dist-packages (from inference) (1.3.2)
# Requirement already satisfied: scikit-image>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from inference) (0.19.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from inference) (1.0.0)
# Requirement already satisfied: wheel>=0.38.1 in /usr/local/lib/python3.10/dist-packages (from inference) (0.43.0)
# Requirement already satisfied: setuptools<70.0.0,>=65.5.1 in /usr/local/lib/python3.10/dist-packages (from inference) (67.7.2)
# Requirement already satisfied: pytest-asyncio<=0.21.1 in /usr/local/lib/python3.10/dist-packages (from inference) (0.21.1)
# Requirement already satisfied: networkx>=3.1 in /usr/local/lib/python3.10/dist-packages (from inference) (3.3)
# Requirement already satisfied: pydantic~=2.6 in /usr/local/lib/python3.10/dist-packages (from inference) (2.8.2)
# Requirement already satisfied: openai>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from inference) (1.35.13)
# Requirement already satisfied: structlog>=24.1.0 in /usr/local/lib/python3.10/dist-packages (from inference) (24.2.0)
# Requirement already satisfied: zxing-cpp>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from inference) (2.2.0)
# Requirement already satisfied: boto3<=1.34.123 in /usr/local/lib/python3.10/dist-packages (from inference) (1.34.123)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from inference) (4.12.2)
# Requirement already satisfied: pydot>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from inference) (2.0.0)
# Requirement already satisfied: shapely<2.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from inference) (2.0.4)
# Requirement already satisfied: tldextract~=5.1.2 in /usr/local/lib/python3.10/dist-packages (from inference) (5.1.2)
# Requirement already satisfied: onnxruntime<=1.15.1 in /usr/local/lib/python3.10/dist-packages (from inference) (1.15.1)
# Requirement already satisfied: GPUtil==1.4.0 in /usr/local/lib/python3.10/dist-packages (from inference) (1.4.0)
# Requirement already satisfied: docker==6.1.3 in /usr/local/lib/python3.10/dist-packages (from inference) (6.1.3)
# Requirement already satisfied: typer==0.9.0 in /usr/local/lib/python3.10/dist-packages (from inference) (0.9.0)
# Requirement already satisfied: skypilot[aws,gcp]==0.5.0 in /usr/local/lib/python3.10/dist-packages (from inference) (0.5.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from inference) (6.0.1)
# Requirement already satisfied: tqdm>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from inference) (4.66.4)
# Requirement already satisfied: py-cpuinfo>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from inference) (9.0.0)
# Requirement already satisfied: aiohttp>=3.9.0 in /usr/local/lib/python3.10/dist-packages (from inference) (3.9.5)
# Requirement already satisfied: backoff>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from inference) (2.2.1)
# Requirement already satisfied: dataclasses-json>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from inference) (0.6.7)
# Requirement already satisfied: aioresponses>=0.7.6 in /usr/local/lib/python3.10/dist-packages (from inference) (0.7.6)
# Requirement already satisfied: packaging>=14.0 in /usr/local/lib/python3.10/dist-packages (from docker==6.1.3->inference) (24.1)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from docker==6.1.3->inference) (1.26.19)
# Requirement already satisfied: websocket-client>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from docker==6.1.3->inference) (1.8.0)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from skypilot[aws,gcp]==0.5.0->inference) (5.3.3)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from skypilot[aws,gcp]==0.5.0->inference) (8.1.7)
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (from skypilot[aws,gcp]==0.5.0->inference) (0.4.4)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.10/dist-packages (from skypilot[aws,gcp]==0.5.0->inference) (42.0.8)
# Requirement already satisfied: jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from skypilot[aws,gcp]==0.5.0->inference) (3.1.4)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from skypilot[aws,gcp]==0.5.0->inference) (4.19.2)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from skypilot[aws,gcp]==0.5.0->inference) (2.0.3)
# Requirement already satisfied: pendulum in /usr/local/lib/python3.10/dist-packages (from skypilot[aws,gcp]==0.5.0->inference) (3.0.0)
# Requirement already satisfied: PrettyTable>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from skypilot[aws,gcp]==0.5.0->inference) (3.10.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from skypilot[aws,gcp]==0.5.0->inference) (0.9.0)
# Requirement already satisfied: filelock>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from skypilot[aws,gcp]==0.5.0->inference) (3.15.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from skypilot[aws,gcp]==0.5.0->inference) (5.9.5)
# Requirement already satisfied: pulp in /usr/local/lib/python3.10/dist-packages (from skypilot[aws,gcp]==0.5.0->inference) (2.9.0)
# Requirement already satisfied: awscli>=1.27.10 in /usr/local/lib/python3.10/dist-packages (from skypilot[aws,gcp]==0.5.0->inference) (1.33.26)
# Requirement already satisfied: botocore>=1.29.10 in /usr/local/lib/python3.10/dist-packages (from skypilot[aws,gcp]==0.5.0->inference) (1.34.144)
# Requirement already satisfied: google-api-python-client>=2.69.0 in /usr/local/lib/python3.10/dist-packages (from skypilot[aws,gcp]==0.5.0->inference) (2.84.0)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.10/dist-packages (from skypilot[aws,gcp]==0.5.0->inference) (2.8.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.9.0->inference) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.9.0->inference) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.9.0->inference) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.9.0->inference) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.9.0->inference) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.9.0->inference) (4.0.3)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from APScheduler<=3.10.1->inference) (1.16.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from APScheduler<=3.10.1->inference) (2023.4)
# Requirement already satisfied: tzlocal!=3.*,>=2.0 in /usr/local/lib/python3.10/dist-packages (from APScheduler<=3.10.1->inference) (5.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from boto3<=1.34.123->inference) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from boto3<=1.34.123->inference) (0.10.2)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json>=0.6.0->inference) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json>=0.6.0->inference) (0.9.0)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /usr/local/lib/python3.10/dist-packages (from fastapi<0.111,>=0.100->inference) (0.37.2)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from onnxruntime<=1.15.1->inference) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime<=1.15.1->inference) (24.3.25)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime<=1.15.1->inference) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime<=1.15.1->inference) (1.13.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.12.0->inference) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.12.0->inference) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.12.0->inference) (0.27.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai>=1.12.0->inference) (1.3.1)
# Requirement already satisfied: prometheus-client<1.0.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from prometheus-fastapi-instrumentator<=6.0.0->inference) (0.20.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic~=2.6->inference) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic~=2.6->inference) (2.20.1)
# Requirement already satisfied: pyparsing>=3 in /usr/local/lib/python3.10/dist-packages (from pydot>=2.0.0->inference) (3.1.2)
# Requirement already satisfied: pytest>=7.0.0 in /usr/local/lib/python3.10/dist-packages (from pytest-asyncio<=0.21.1->inference) (7.4.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->inference) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->inference) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->inference) (2024.7.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<=13.5.2->inference) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<=13.5.2->inference) (2.16.1)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.19.0->inference) (1.11.4)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.19.0->inference) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.19.0->inference) (2024.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.19.0->inference) (1.6.0)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from supervision<1.0.0,>=0.20.0->inference) (0.7.1)
# Requirement already satisfied: matplotlib>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from supervision<1.0.0,>=0.20.0->inference) (3.7.1)
# Requirement already satisfied: opencv-python-headless>=4.5.5.64 in /usr/local/lib/python3.10/dist-packages (from supervision<1.0.0,>=0.20.0->inference) (4.10.0.84)
# Requirement already satisfied: requests-file>=1.4 in /usr/local/lib/python3.10/dist-packages (from tldextract~=5.1.2->inference) (2.1.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai>=1.12.0->inference) (1.2.1)
# Requirement already satisfied: docutils<0.17,>=0.10 in /usr/local/lib/python3.10/dist-packages (from awscli>=1.27.10->skypilot[aws,gcp]==0.5.0->inference) (0.16)
# Requirement already satisfied: rsa<4.8,>=3.1.2 in /usr/local/lib/python3.10/dist-packages (from awscli>=1.27.10->skypilot[aws,gcp]==0.5.0->inference) (4.7.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore>=1.29.10->skypilot[aws,gcp]==0.5.0->inference) (2.8.2)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference) (2.27.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference) (0.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference) (2.16.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference) (4.1.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai>=1.12.0->inference) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.12.0->inference) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=3.0->skypilot[aws,gcp]==0.5.0->inference) (2.1.5)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<=13.5.2->inference) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->supervision<1.0.0,>=0.20.0->inference) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->supervision<1.0.0,>=0.20.0->inference) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->supervision<1.0.0,>=0.20.0->inference) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->supervision<1.0.0,>=0.20.0->inference) (1.4.5)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->skypilot[aws,gcp]==0.5.0->inference) (2024.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from PrettyTable>=2.0.0->skypilot[aws,gcp]==0.5.0->inference) (0.2.13)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.10/dist-packages (from pytest>=7.0.0->pytest-asyncio<=0.21.1->inference) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /usr/local/lib/python3.10/dist-packages (from pytest>=7.0.0->pytest-asyncio<=0.21.1->inference) (1.5.0)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pytest>=7.0.0->pytest-asyncio<=0.21.1->inference) (2.0.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json>=0.6.0->inference) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->onnxruntime<=1.15.1->inference) (10.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography->skypilot[aws,gcp]==0.5.0->inference) (1.16.0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage->skypilot[aws,gcp]==0.5.0->inference) (2.3.3)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage->skypilot[aws,gcp]==0.5.0->inference) (2.7.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->skypilot[aws,gcp]==0.5.0->inference) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->skypilot[aws,gcp]==0.5.0->inference) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->skypilot[aws,gcp]==0.5.0->inference) (0.19.0)
# Requirement already satisfied: time-machine>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from pendulum->skypilot[aws,gcp]==0.5.0->inference) (2.14.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime<=1.15.1->inference) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography->skypilot[aws,gcp]==0.5.0->inference) (2.22)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference) (1.63.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=2.69.0->skypilot[aws,gcp]==0.5.0->inference) (0.4.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-resumable-media>=2.3.2->google-cloud-storage->skypilot[aws,gcp]==0.5.0->inference) (1.5.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from rsa<4.8,>=3.1.2->awscli>=1.27.10->skypilot[aws,gcp]==0.5.0->inference) (0.6.0)

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import os
import pandas as pd
import cv2
import numpy as np
from PIL import Image
from inference_sdk import InferenceHTTPClient
import base64

# Khởi tạo khách hàng inference
CLIENT = InferenceHTTPClient(
    api_url="https://infer.roboflow.com",
    api_key="EsWsf3IC9J62FVE6Jk1O" # thay bằng api của bạn
)

# Danh sách các ảnh cần xử lý
image_files = [
    "1.png"
]

# Đường dẫn tới file Excel
excel_file_path = "/content/ocr_base64.xlsx"

def preprocess_image(image_path):
    # Đọc ảnh
    img = cv2.imread(image_path)

    # Chuyển sang ảnh xám
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Áp dụng Gaussian blur để giảm nhiễu
    blurred = cv2.GaussianBlur(gray, (3, 3), 0)

    # Áp dụng adaptive thresholding
    thresh = cv2.adaptiveThreshold(blurred, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 11, 2)

    # Áp dụng morphological operations để làm sạch ảnh
    kernel = np.ones((2,2), np.uint8)
    cleaned = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel)

    # Chuyển đổi lại thành định dạng PIL Image
    pil_img = Image.fromarray(cleaned)

    # Lưu ảnh đã xử lý
    preprocessed_path = f"preprocessed_{os.path.basename(image_path)}"
    pil_img.save(preprocessed_path)

    return preprocessed_path

def postprocess_result(text):
    # Loại bỏ khoảng trắng
    text = text.strip().lower()

    # Loại bỏ các ký tự không phải chữ cái hoặc số
    cleaned_text = ''.join(c for c in text if c.isalnum())

    # Chuyển đổi 'O' thành '0' và 'I' thành '1' (thường gặp trong CAPTCHA)
    cleaned_text = cleaned_text.replace('O', '0').replace('I', '1')

    # Giới hạn độ dài (giả sử CAPTCHA có độ dài cố định là 6)
    return cleaned_text[:7]
# Hàm để phân tích kết quả OCR
def parse_ocr_result(result, image_name):
    raw_text = result.get("result", "")
    processed_text = postprocess_result(raw_text)

    return {
        "Image Name": image_name,
        "Processed Result": processed_text
    }


# Hàm để thêm dữ liệu vào file Excel
def append_to_excel(df, file_path):
    if os.path.exists(file_path):
        # Nếu file tồn tại, thêm dữ liệu vào file hiện có
        existing_df = pd.read_excel(file_path)
        updated_df = pd.concat([existing_df, df], ignore_index=True)
    else:
        # Nếu file không tồn tại, tạo một DataFrame mới
        updated_df = df

    # Lưu DataFrame đã cập nhật vào file Excel
    updated_df.to_excel(file_path, index=False)

# Danh sách để lưu các kết quả đã phân tích
all_data = []

# Lặp qua các ảnh và thực hiện OCR
for image_file in image_files:
    # Thực hiện OCR trên ảnh
    result = CLIENT.ocr_image(inference_input=image_file)
    # Phân tích kết quả OCR
    parsed_data = parse_ocr_result(result, os.path.basename(image_file))
    all_data.append(parsed_data)

# Tạo DataFrame từ tất cả các kết quả đã phân tích
df = pd.DataFrame(all_data)

# Thêm dữ liệu đã phân tích vào file Excel
append_to_excel(df, excel_file_path)

print(f"Dữ liệu đã được lưu vào {excel_file_path}")
# Out:
# Dữ liệu đã được lưu vào /content/ocr_base64.xlsx

# %%
import os
import pandas as pd
import cv2
import numpy as np
from PIL import Image
from inference_sdk import InferenceHTTPClient
import base64

# Khởi tạo khách hàng inference
CLIENT = InferenceHTTPClient(
    api_url="https://infer.roboflow.com",
    api_key="qttWvOfq2j0uBMG7Xf0y" # thay bằng api của bạn
)

# Danh sách các ảnh cần xử lý
image_files = [
    "2.png"
]

def image_to_base64(image_path):
    with open(image_path, "rb") as image_file:
        base64_string = base64.b64encode(image_file.read()).decode('utf-8')
        print(f"Base64 string for {image_path}:", base64_string[:100], "...")  # In chuỗi base64 ra terminal (in 100 ký tự đầu tiên)
        return base64_string

def preprocess_image(image_path):
    # Đọc ảnh
    img = cv2.imread(image_path)

    # Chuyển sang ảnh xám
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Áp dụng Gaussian blur để giảm nhiễu
    blurred = cv2.GaussianBlur(gray, (3, 3), 0)

    # Áp dụng adaptive thresholding
    thresh = cv2.adaptiveThreshold(blurred, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 11, 2)

    # Áp dụng morphological operations để làm sạch ảnh
    kernel = np.ones((2,2), np.uint8)
    cleaned = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel)

    # Chuyển đổi lại thành định dạng PIL Image
    pil_img = Image.fromarray(cleaned)

    # Lưu ảnh đã xử lý
    preprocessed_path = f"preprocessed_{os.path.basename(image_path)}"
    pil_img.save(preprocessed_path)

    return preprocessed_path

def postprocess_result(text):
    # Loại bỏ khoảng trắng
    text = text.strip().lower()

    # Loại bỏ các ký tự không phải chữ cái hoặc số
    cleaned_text = ''.join(c for c in text if c.isalnum())

    # Chuyển đổi 'O' thành '0' và 'I' thành '1' (thường gặp trong CAPTCHA)
    cleaned_text = cleaned_text.replace('O', '0').replace('I', '1')

    # Giới hạn độ dài (giả sử CAPTCHA có độ dài cố định là 6)
    return cleaned_text[:7]

# Hàm để phân tích kết quả OCR
def parse_ocr_result(result, image_name):
    raw_text = result.get("result", "")
    processed_text = postprocess_result(raw_text)

    return {
        "Image Name": image_name,
        "Processed Result": processed_text
    }

# Danh sách để lưu các kết quả đã phân tích
all_data = []

# Lặp qua các ảnh và thực hiện OCR
for image_file in image_files:
    # Chuyển ảnh sang base64
    base64_image = image_to_base64(image_file)

    # Thực hiện OCR trên ảnh base64
    result = CLIENT.ocr_image(inference_input=base64_image)

    # Phân tích kết quả OCR
    parsed_data = parse_ocr_result(result, os.path.basename(image_file))
    all_data.append(parsed_data)
    print(parsed_data)  # In kết quả ra terminal

# Tạo DataFrame từ tất cả các kết quả đã phân tích
df = pd.DataFrame(all_data)
print(df)  # In DataFrame ra terminal
# Out:
# Base64 string for 2.png: /9j/4AAQSkZJRgABAQEASABIAAD//gA+Q1JFQVRPUjogZ2QtanBlZyB2MS4wICh1c2luZyBJSkcgSlBFRyB2ODApLCBkZWZhdWx0 ...
# {'Image Name': '2.png', 'Processed Result': 'nddmdw'}
#   Image Name Processed Result
# 0      2.png           nddmdw

# %%
import base64

def text_to_base64(text):

    text_bytes = text.encode('utf-8')


    base64_bytes = base64.b64encode(text_bytes)


    base64_string = base64_bytes.decode('utf-8')

    return base64_string


text = "vqcc5j"
base64_result = text_to_base64(text)
print(f"Original text: {text}")
print(f"Base64 encoded: {base64_result}")
# Out:
# Original text: vqcc5j
# Base64 encoded: dnFjYzVq

# %%
import os
import pandas as pd
from inference_sdk import InferenceHTTPClient

# Khởi tạo khách hàng inference
CLIENT = InferenceHTTPClient(
    api_url="https://infer.roboflow.com",
    api_key="qttWvOfq2j0uBMG7Xf0y" # thay bằng api của bạn
)

# Danh sách các ảnh cần xử lý
image_files = [

    "1.png",
    "2.png",
    "3.png",
    "4.png",
    "5.png",
    "6.png",
    "7.png",
    "8.png"
]

# Đường dẫn tới file Excel
excel_file_path = "/content/ocrcaptcha.xlsx"

# Hàm để phân tích kết quả OCR
def parse_ocr_result(result, image_name):
    return {
        "Image Name": image_name,
        "Result": result.get("result", "")
    }

# Hàm để thêm dữ liệu vào file Excel
def append_to_excel(df, file_path):
    if os.path.exists(file_path):
        # Nếu file tồn tại, thêm dữ liệu vào file hiện có
        existing_df = pd.read_excel(file_path)
        updated_df = pd.concat([existing_df, df], ignore_index=True)
    else:
        # Nếu file không tồn tại, tạo một DataFrame mới
        updated_df = df

    # Lưu DataFrame đã cập nhật vào file Excel
    updated_df.to_excel(file_path, index=False)

# Danh sách để lưu các kết quả đã phân tích
all_data = []

# Lặp qua các ảnh và thực hiện OCR
for image_file in image_files:
    # Thực hiện OCR trên ảnh
    result = CLIENT.ocr_image(inference_input=image_file)

    # In kết quả
    print(result)

    # Phân tích kết quả OCR
    parsed_data = parse_ocr_result(result, os.path.basename(image_file))
    all_data.append(parsed_data)

# Tạo DataFrame từ tất cả các kết quả đã phân tích
df = pd.DataFrame(all_data)

# Thêm dữ liệu đã phân tích vào file Excel
append_to_excel(df, excel_file_path)

print(f"Dữ liệu đã được lưu vào {excel_file_path}")
# Out:
# {'result': 'vqcc5, J -', 'time': 1.5120850140001494, 'parent_id': None}
# {'result': 'nddmdw', 'time': 1.5530674480000926, 'parent_id': None}
# {'result': '3wyqc9', 'time': 1.4337150139999721, 'parent_id': None}
# {'result': '6v6sj2', 'time': 1.5459657910000715, 'parent_id': None}
# {'result': 'XWZ 46p', 'time': 1.512343518000307, 'parent_id': None}
# {'result': '3f. /. Z 83', 'time': 1.4889416139999412, 'parent_id': None}
# {'result': 't76rgt L', 'time': 1.4522427620004237, 'parent_id': None}
# {'result': 'dmtrgz', 'time': 1.4663603539997894, 'parent_id': None}
# Dữ liệu đã được lưu vào /content/ocrcaptcha.xlsx

# %%
pip install python-doctr
# Out:
# Collecting python-doctr
#   Downloading python_doctr-0.8.1-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from python-doctr) (8.0.0)
# Requirement already satisfied: numpy<2.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr) (1.25.2)
# Requirement already satisfied: scipy<2.0.0,>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr) (1.11.4)
# Requirement already satisfied: h5py<4.0.0,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr) (3.9.0)
# Requirement already satisfied: opencv-python<5.0.0,>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr) (4.8.0.76)
# Collecting pypdfium2<5.0.0,>=4.0.0 (from python-doctr)
#   Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 33.1 MB/s eta 0:00:00
# Collecting pyclipper<2.0.0,>=1.2.0 (from python-doctr)
#   Downloading pyclipper-1.3.0.post5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (908 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 44.9 MB/s eta 0:00:00
# Requirement already satisfied: shapely<3.0.0,>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr) (2.0.4)
# Collecting langdetect<2.0.0,>=1.0.9 (from python-doctr)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 45.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting rapidfuzz<4.0.0,>=3.0.0 (from python-doctr)
#   Downloading rapidfuzz-3.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 57.3 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr) (0.23.4)
# Requirement already satisfied: matplotlib>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr) (3.7.1)
# Collecting weasyprint>=55.0 (from python-doctr)
#   Downloading weasyprint-62.3-py3-none-any.whl (289 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.3/289.3 kB 22.8 MB/s eta 0:00:00
# Requirement already satisfied: Pillow>=9.2.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr) (9.4.0)
# Requirement already satisfied: defusedxml>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr) (0.7.1)
# Collecting mplcursors>=0.3 (from python-doctr)
#   Downloading mplcursors-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.8/88.8 kB 9.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting unidecode>=1.0.0 (from python-doctr)
#   Downloading Unidecode-1.3.8-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 21.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.30.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr) (4.66.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr) (4.12.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect<2.0.0,>=1.0.9->python-doctr) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->python-doctr) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->python-doctr) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->python-doctr) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->python-doctr) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->python-doctr) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->python-doctr) (2.8.2)
# Collecting matplotlib>=3.1.0 (from python-doctr)
#   Downloading matplotlib-3.9.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 81.1 MB/s eta 0:00:00
# Collecting pydyf>=0.10.0 (from weasyprint>=55.0->python-doctr)
#   Downloading pydyf-0.11.0-py3-none-any.whl (8.1 kB)
# Requirement already satisfied: cffi>=0.6 in /usr/local/lib/python3.10/dist-packages (from weasyprint>=55.0->python-doctr) (1.16.0)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from weasyprint>=55.0->python-doctr) (1.1)
# Requirement already satisfied: tinycss2>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from weasyprint>=55.0->python-doctr) (1.3.0)
# Collecting cssselect2>=0.1 (from weasyprint>=55.0->python-doctr)
#   Downloading cssselect2-0.7.0-py3-none-any.whl (15 kB)
# Collecting Pyphen>=0.9.1 (from weasyprint>=55.0->python-doctr)
#   Downloading pyphen-0.15.0-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 69.3 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->python-doctr) (3.19.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=0.6->weasyprint>=55.0->python-doctr) (2.22)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from cssselect2>=0.1->weasyprint>=55.0->python-doctr) (0.5.1)
# Collecting zopfli>=0.1.4 (from fonttools>=4.22.0->matplotlib>=3.1.0->python-doctr)
#   Downloading zopfli-0.2.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (848 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 848.9/848.9 kB 48.5 MB/s eta 0:00:00
# Collecting brotli>=1.0.1 (from fonttools>=4.22.0->matplotlib>=3.1.0->python-doctr)
#   Downloading Brotli-1.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 73.1 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0.0,>=0.20.0->python-doctr) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0.0,>=0.20.0->python-doctr) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0.0,>=0.20.0->python-doctr) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0.0,>=0.20.0->python-doctr) (2024.7.4)
# Building wheels for collected packages: langdetect, mplcursors
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993227 sha256=b5100050ed3c3abbb386a30f197219d81207d19fc21807ad3cef88a8095f4180
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
#   Building wheel for mplcursors (pyproject.toml) ... done
#   Created wheel for mplcursors: filename=mplcursors-0.5.3-py3-none-any.whl size=20727 sha256=2c455cf04dfa6110309ebf2bc834ea629cbf10a9af7f1ac84b2aeeac792e8524
#   Stored in directory: /root/.cache/pip/wheels/83/43/92/44f9515471f56877c774a515a2902d3e5484ea1bc7fd412d03
# Successfully built langdetect mplcursors
# Installing collected packages: pyclipper, brotli, zopfli, unidecode, rapidfuzz, Pyphen, pypdfium2, pydyf, langdetect, matplotlib, cssselect2, weasyprint, mplcursors, python-doctr
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
# Successfully installed Pyphen-0.15.0 brotli-1.1.0 cssselect2-0.7.0 langdetect-1.0.9 matplotlib-3.9.1 mplcursors-0.5.3 pyclipper-1.3.0.post5 pydyf-0.11.0 pypdfium2-4.30.0 python-doctr-0.8.1 rapidfuzz-3.9.4 unidecode-1.3.8 weasyprint-62.3 zopfli-0.2.3

# %%
pip install "python-doctr[tf]"
# Out:
# Requirement already satisfied: python-doctr[tf] in /usr/local/lib/python3.10/dist-packages (0.8.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from python-doctr[tf]) (8.0.0)
# Requirement already satisfied: numpy<2.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[tf]) (1.25.2)
# Requirement already satisfied: scipy<2.0.0,>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[tf]) (1.11.4)
# Requirement already satisfied: h5py<4.0.0,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[tf]) (3.9.0)
# Requirement already satisfied: opencv-python<5.0.0,>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[tf]) (4.8.0.76)
# Requirement already satisfied: pypdfium2<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[tf]) (4.30.0)
# Requirement already satisfied: pyclipper<2.0.0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[tf]) (1.3.0.post5)
# Requirement already satisfied: shapely<3.0.0,>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[tf]) (2.0.4)
# Requirement already satisfied: langdetect<2.0.0,>=1.0.9 in /usr/local/lib/python3.10/dist-packages (from python-doctr[tf]) (1.0.9)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[tf]) (3.9.4)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[tf]) (0.23.4)
# Requirement already satisfied: matplotlib>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[tf]) (3.9.1)
# Requirement already satisfied: weasyprint>=55.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[tf]) (62.3)
# Requirement already satisfied: Pillow>=9.2.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[tf]) (9.4.0)
# Requirement already satisfied: defusedxml>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[tf]) (0.7.1)
# Requirement already satisfied: mplcursors>=0.3 in /usr/local/lib/python3.10/dist-packages (from python-doctr[tf]) (0.5.3)
# Requirement already satisfied: unidecode>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[tf]) (1.3.8)
# Requirement already satisfied: tqdm>=4.30.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[tf]) (4.66.4)
# Requirement already satisfied: tensorflow<2.16.0,>=2.11.0 in /usr/local/lib/python3.10/dist-packages (from python-doctr[tf]) (2.15.0)
# Collecting tf2onnx<2.0.0,>=1.16.0 (from python-doctr[tf])
#   Downloading tf2onnx-1.16.1-py3-none-any.whl (455 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.8/455.8 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr[tf]) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr[tf]) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr[tf]) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr[tf]) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr[tf]) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr[tf]) (4.12.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect<2.0.0,>=1.0.9->python-doctr[tf]) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->python-doctr[tf]) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->python-doctr[tf]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->python-doctr[tf]) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->python-doctr[tf]) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->python-doctr[tf]) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->python-doctr[tf]) (2.8.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16.0,>=2.11.0->python-doctr[tf]) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16.0,>=2.11.0->python-doctr[tf]) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16.0,>=2.11.0->python-doctr[tf]) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16.0,>=2.11.0->python-doctr[tf]) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16.0,>=2.11.0->python-doctr[tf]) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16.0,>=2.11.0->python-doctr[tf]) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16.0,>=2.11.0->python-doctr[tf]) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16.0,>=2.11.0->python-doctr[tf]) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16.0,>=2.11.0->python-doctr[tf]) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16.0,>=2.11.0->python-doctr[tf]) (67.7.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16.0,>=2.11.0->python-doctr[tf]) (2.4.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16.0,>=2.11.0->python-doctr[tf]) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16.0,>=2.11.0->python-doctr[tf]) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16.0,>=2.11.0->python-doctr[tf]) (1.64.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16.0,>=2.11.0->python-doctr[tf]) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16.0,>=2.11.0->python-doctr[tf]) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16.0,>=2.11.0->python-doctr[tf]) (2.15.0)
# Collecting onnx>=1.4.1 (from tf2onnx<2.0.0,>=1.16.0->python-doctr[tf])
#   Downloading onnx-1.16.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 48.8 MB/s eta 0:00:00
# Requirement already satisfied: pydyf>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from weasyprint>=55.0->python-doctr[tf]) (0.11.0)
# Requirement already satisfied: cffi>=0.6 in /usr/local/lib/python3.10/dist-packages (from weasyprint>=55.0->python-doctr[tf]) (1.16.0)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from weasyprint>=55.0->python-doctr[tf]) (1.1)
# Requirement already satisfied: tinycss2>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from weasyprint>=55.0->python-doctr[tf]) (1.3.0)
# Requirement already satisfied: cssselect2>=0.1 in /usr/local/lib/python3.10/dist-packages (from weasyprint>=55.0->python-doctr[tf]) (0.7.0)
# Requirement already satisfied: Pyphen>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from weasyprint>=55.0->python-doctr[tf]) (0.15.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->python-doctr[tf]) (3.19.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow<2.16.0,>=2.11.0->python-doctr[tf]) (0.43.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=0.6->weasyprint>=55.0->python-doctr[tf]) (2.22)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from cssselect2>=0.1->weasyprint>=55.0->python-doctr[tf]) (0.5.1)
# Requirement already satisfied: zopfli>=0.1.4 in /usr/local/lib/python3.10/dist-packages (from fonttools>=4.22.0->matplotlib>=3.1.0->python-doctr[tf]) (0.2.3)
# Requirement already satisfied: brotli>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from fonttools>=4.22.0->matplotlib>=3.1.0->python-doctr[tf]) (1.1.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16.0,>=2.11.0->python-doctr[tf]) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16.0,>=2.11.0->python-doctr[tf]) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16.0,>=2.11.0->python-doctr[tf]) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16.0,>=2.11.0->python-doctr[tf]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16.0,>=2.11.0->python-doctr[tf]) (3.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0.0,>=0.20.0->python-doctr[tf]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0.0,>=0.20.0->python-doctr[tf]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0.0,>=0.20.0->python-doctr[tf]) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0.0,>=0.20.0->python-doctr[tf]) (2024.7.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16.0,>=2.11.0->python-doctr[tf]) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16.0,>=2.11.0->python-doctr[tf]) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16.0,>=2.11.0->python-doctr[tf]) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow<2.16.0,>=2.11.0->python-doctr[tf]) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow<2.16.0,>=2.11.0->python-doctr[tf]) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16.0,>=2.11.0->python-doctr[tf]) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow<2.16.0,>=2.11.0->python-doctr[tf]) (3.2.2)
# Installing collected packages: onnx, tf2onnx
# Successfully installed onnx-1.16.1 tf2onnx-1.16.1
